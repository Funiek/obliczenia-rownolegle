# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np
from matplotlib.tri import Triangulation
from matplotlib.ticker import ScalarFormatter

# %%
df = pd.read_csv('wyniki.csv')
df
# Out:
#      Ilość bajtów  Ilość cykli  Czas trwania wszystkich operacji - Blokujące  \
# 0               1            1                                      0.000016
# 1               1            2                                      0.000133
# 2               1            4                                      0.000501
# 3               1            8                                      0.001040
# 4               1           16                                      0.002019
# ..            ...          ...                                           ...
# 251         32768         2048                                      2.256965
# 252         32768         4096                                      4.545107
# 253         32768         8192                                      9.089746
# 254         32768        16384                                     18.181238
# 255         32768        32768                                     36.222488
#
#      Przepustowość łącza - Blokujące  \
# ...

# %%
x = df['Ilość bajtów']
y = df['Ilość cykli']
z = df['Czas trwania wszystkich operacji - Blokujące']

# Inicjalizuj wykres 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Ustal etykiety osi
ax.set_xlabel('Ilość bajtów')
ax.set_ylabel('Ilość cykli')
ax.set_zlabel('Czas trwania wszystkich operacji - Blokujące')
#ax.set_xticks(np.arange(0, 32769, 128))
#ax.set_yticks(np.arange(0, 32769, 128))

#ax.set_xlim(0, 32768)  # Zakres dla osi X
#ax.set_ylim(0, 32768)  # Zakres dla osi Y

# Tworzenie triangulacji punktów
tri = Triangulation(x, y)

# Utwórz wykres 3D z wypełnieniem między punktami
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap='viridis', linewidth=0.2)
plt.savefig('Czas trwania wszystkich operacji - Blokujące.png', dpi=300)
# Wyświetl wykres

#ax.view_init(30, -90) 
plt.show()

# %%
x = df['Ilość bajtów']
y = df['Ilość cykli']
z = df['Czas trwania wszystkich operacji - Nieblokujące']

# Inicjalizuj wykres 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Ustal etykiety osi
ax.set_xlabel('Ilość bajtów')
ax.set_ylabel('Ilość cykli')
ax.set_zlabel('Czas trwania wszystkich operacji - Nieblokujące')
#ax.set_xticks(np.arange(0, 32769, 128))
#ax.set_yticks(np.arange(0, 32769, 128))

#ax.set_xlim(0, 32768)  # Zakres dla osi X
#ax.set_ylim(0, 32768)  # Zakres dla osi Y

# Tworzenie triangulacji punktów
tri = Triangulation(x, y)

# Utwórz wykres 3D z wypełnieniem między punktami
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap='viridis', linewidth=0.2)
plt.savefig('Czas trwania wszystkich operacji - Nieblokujące.png', dpi=300)
# Wyświetl wykres

#ax.view_init(30, -90) 
plt.show()

# %%
x = df['Ilość bajtów']
y = df['Ilość cykli']
z = df['Przepustowość łącza - Blokujące']

# Inicjalizuj wykres 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Ustal etykiety osi
ax.set_xlabel('Ilość bajtów')
ax.set_ylabel('Ilość cykli')
ax.set_zlabel('Przepustowość łącza - Blokujące')
#ax.set_xticks(np.arange(0, 32769, 128))
#ax.set_yticks(np.arange(0, 32769, 128))

#ax.set_xlim(0, 32768)  # Zakres dla osi X
#ax.set_ylim(0, 32768)  # Zakres dla osi Y

# Tworzenie triangulacji punktów
tri = Triangulation(x, y)

# Utwórz wykres 3D z wypełnieniem między punktami
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap='viridis', linewidth=0.2)
plt.savefig('Przepustowość łącza - Blokujące.png', dpi=300)
# Wyświetl wykres

#ax.view_init(30, -90) 
plt.show()

# %%
x = df['Ilość bajtów']
y = df['Ilość cykli']
z = df['Przepustowość łącza - Nieblokujące']

# Inicjalizuj wykres 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Ustal etykiety osi
ax.set_xlabel('Ilość bajtów')
ax.set_ylabel('Ilość cykli')
ax.set_zlabel('Przepustowość łącza - Nieblokujące')
#ax.set_xticks(np.arange(0, 32769, 128))
#ax.set_yticks(np.arange(0, 32769, 128))

#ax.set_xlim(0, 32768)  # Zakres dla osi X
#ax.set_ylim(0, 32768)  # Zakres dla osi Y

# Tworzenie triangulacji punktów
tri = Triangulation(x, y)

# Utwórz wykres 3D z wypełnieniem między punktami
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap='viridis', linewidth=0.2)
plt.savefig('Przepustowość łącza - Nieblokujące.png', dpi=300)
# Wyświetl wykres

#ax.view_init(30, -90) 
plt.show()

# %%
x = df['Ilość bajtów']
y = df['Ilość cykli']
z = df['Czas wykonania pojedynczej operacji - Blokujące']

# Inicjalizuj wykres 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Ustal etykiety osi
ax.set_xlabel('Ilość bajtów')
ax.set_ylabel('Ilość cykli')
ax.set_zlabel('Czas wykonania pojedynczej operacji - Blokujące')
#ax.set_xticks(np.arange(0, 32769, 128))
#ax.set_yticks(np.arange(0, 32769, 128))

#ax.set_xlim(0, 32768)  # Zakres dla osi X
#ax.set_ylim(0, 32768)  # Zakres dla osi Y

# Tworzenie triangulacji punktów
tri = Triangulation(x, y)

# Utwórz wykres 3D z wypełnieniem między punktami
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap='viridis', linewidth=0.2)
plt.savefig('Czas wykonania pojedynczej operacji - Blokujące.png', dpi=300)
# Wyświetl wykres

#ax.view_init(30, -90) 
plt.show()

# %%
x = df['Ilość bajtów']
y = df['Ilość cykli']
z = df['Czas wykonania pojedynczej operacji - Nieblokujące']

# Inicjalizuj wykres 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Ustal etykiety osi
ax.set_xlabel('Ilość bajtów')
ax.set_ylabel('Ilość cykli')
ax.set_zlabel('Czas wykonania pojedynczej operacji - Nieblokujące')
#ax.set_xticks(np.arange(0, 32769, 128))
#ax.set_yticks(np.arange(0, 32769, 128))

#ax.set_xlim(0, 32768)  # Zakres dla osi X
#ax.set_ylim(0, 32768)  # Zakres dla osi Y

# Tworzenie triangulacji punktów
tri = Triangulation(x, y)

# Utwórz wykres 3D z wypełnieniem między punktami
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap='viridis', linewidth=0.2)
plt.savefig('Czas wykonania pojedynczej operacji - Nieblokujące.png', dpi=300)
# Wyświetl wykres

#ax.view_init(30, -90) 
plt.show()

# %%
df_1 = df[df['Ilość bajtów']==1]
df_2048 = df[df['Ilość bajtów']==2048]
df_32768 = df[df['Ilość bajtów']==32768]

# %%
x1_1 = df_1['Ilość cykli']
y1_1 = df_1['Czas trwania wszystkich operacji - Blokujące']
x2_1 = df_1['Ilość cykli']
y2_1 = df_1['Czas trwania wszystkich operacji - Nieblokujące']
###############################################################
x1_2048 = df_2048['Ilość cykli']
y1_2048 = df_2048['Czas trwania wszystkich operacji - Blokujące']
x2_2048 = df_2048['Ilość cykli']
y2_2048 = df_2048['Czas trwania wszystkich operacji - Nieblokujące']
###############################################################
x1_32768 = df_32768['Ilość cykli']
y1_32768 = df_32768['Czas trwania wszystkich operacji - Blokujące']
x2_32768 = df_32768['Ilość cykli']
y2_32768 = df_32768['Czas trwania wszystkich operacji - Nieblokujące']
###############################################################

plt.plot(x1_1, y1_1, linestyle='solid', color='b', label='Blokujące - 1B')
plt.plot(x2_1, y2_1, linestyle='dotted', color='b', label='Nieblokujące - 1B')
plt.plot(x1_2048, y1_2048, linestyle='solid', color='r', label='Blokujące - 2048B')
plt.plot(x2_2048, y2_2048, linestyle='dotted', color='r', label='Nieblokujące - 2048B')
plt.plot(x1_32768, y1_32768, linestyle='solid', color='g', label='Blokujące - 32768B')
plt.plot(x2_32768, y2_32768, linestyle='dotted', color='g', label='Nieblokujące - 32768B')

# Dodaj etykiety osi
plt.xlabel('Ilość cykli')
plt.ylabel('Czas trwania wszystkich operacji [s]')

# Dodaj tytuł wykresu
plt.title('Czas trwania wszystkich operacji')
plt.legend()
plt.savefig('Czas trwania wszystkich operacji 2D.png', dpi=300)

# Wyświetl wykres
plt.show()

# %%
x1_1 = df_1['Ilość cykli']
y1_1 = df_1['Przepustowość łącza - Blokujące']/(1024*1024)
x2_1 = df_1['Ilość cykli']
y2_1 = df_1['Przepustowość łącza - Nieblokujące']/(1024*1024)
###############################################################
x1_2048 = df_2048['Ilość cykli']
y1_2048 = df_2048['Przepustowość łącza - Blokujące']/(1024*1024)
x2_2048 = df_2048['Ilość cykli']
y2_2048 = df_2048['Przepustowość łącza - Nieblokujące']/(1024*1024)
###############################################################
x1_32768 = df_32768['Ilość cykli']
y1_32768 = df_32768['Przepustowość łącza - Blokujące']/(1024*1024)
x2_32768 = df_32768['Ilość cykli']
y2_32768 = df_32768['Przepustowość łącza - Nieblokujące']/(1024*1024)
###############################################################

plt.plot(x1_1, y1_1, linestyle='solid', color='b', label='Blokujące - 1B')
plt.plot(x2_1, y2_1, linestyle='dotted', color='b', label='Nieblokujące - 1B')
plt.plot(x1_2048, y1_2048, linestyle='solid', color='r', label='Blokujące - 2048B')
plt.plot(x2_2048, y2_2048, linestyle='dotted', color='r', label='Nieblokujące - 2048B')
plt.plot(x1_32768, y1_32768, linestyle='solid', color='g', label='Blokujące - 32768B')
plt.plot(x2_32768, y2_32768, linestyle='dotted', color='g', label='Nieblokujące - 32768B')


plt.gca().xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
# Dodaj etykiety osi
plt.xlabel('Ilość cykli')
plt.ylabel('Przepustowość łącza [MB/s]')

# Dodaj tytuł wykresu
plt.title('Przepustowość łącza')
plt.legend()
plt.savefig('Przepustowość łącza 2D.png', dpi=300)
# Wyświetl wykres
plt.show()

# %%
x1_1 = df_1['Ilość cykli']
y1_1 = df_1['Czas wykonania pojedynczej operacji - Blokujące']
x2_1 = df_1['Ilość cykli']
y2_1 = df_1['Czas wykonania pojedynczej operacji - Nieblokujące']
###############################################################
x1_2048 = df_2048['Ilość cykli']
y1_2048 = df_2048['Czas wykonania pojedynczej operacji - Blokujące']
x2_2048 = df_2048['Ilość cykli']
y2_2048 = df_2048['Czas wykonania pojedynczej operacji - Nieblokujące']
###############################################################
x1_32768 = df_32768['Ilość cykli']
y1_32768 = df_32768['Czas wykonania pojedynczej operacji - Blokujące']
x2_32768 = df_32768['Ilość cykli']
y2_32768 = df_32768['Czas wykonania pojedynczej operacji - Nieblokujące']
###############################################################

plt.plot(x1_1, y1_1, linestyle='solid', color='b', label='Blokujące - 1B')
plt.plot(x2_1, y2_1, linestyle='dotted', color='b', label='Nieblokujące - 1B')
plt.plot(x1_2048, y1_2048, linestyle='solid', color='r', label='Blokujące - 2048B')
plt.plot(x2_2048, y2_2048, linestyle='dotted', color='r', label='Nieblokujące - 2048B')
plt.plot(x1_32768, y1_32768, linestyle='solid', color='g', label='Blokujące - 32768B')
plt.plot(x2_32768, y2_32768, linestyle='dotted', color='g', label='Nieblokujące - 32768B')

# Dodaj etykiety osi
plt.xlabel('Ilość cykli')
plt.ylabel('Czas wykonania pojedynczej operacji (µs)')

# Dodaj tytuł wykresu
plt.title('Czas wykonania pojedynczej operacji')
plt.legend()
plt.savefig('Czas wykonania pojedynczej operacji 2D.png', dpi=300)
# Wyświetl wykres
plt.show()

# %%
df_temp = df[df['Ilość cykli']==32768]
df_temp
# Out:
#      Ilość bajtów  Ilość cykli  Czas trwania wszystkich operacji - Blokujące  \
# 15              1        32768                                      4.074462
# 31              2        32768                                      4.073452
# 47              4        32768                                      4.083139
# 63              8        32768                                      4.073661
# 79             16        32768                                      4.090322
# 95             32        32768                                      4.299999
# 111            64        32768                                      4.140874
# 127           128        32768                                      4.282572
# 143           256        32768                                      4.075009
# 159           512        32768                                      6.935355
# 175          1024        32768                                      9.895038
# ...

# %%
x1_1 = df_temp['Ilość bajtów']
y1_1 = df_temp['Czas trwania wszystkich operacji - Blokujące']
x2_1 = df_temp['Ilość bajtów']
y2_1 = df_temp['Czas trwania wszystkich operacji - Nieblokujące']

###############################################################

plt.plot(x1_1, y1_1, linestyle='solid', color='r', label='Blokujące')
plt.plot(x2_1, y2_1, linestyle='dotted', color='r', label='Nieblokujące')

# Dodaj etykiety osi
plt.xlabel('Ilość bajtów w wiadomości')
plt.ylabel('Czas trwania wszystkich operacji [s]')

# Dodaj tytuł wykresu
plt.title('Czas trwania wszystkich operacji')
plt.legend()
plt.savefig('Czas trwania wszystkich operacji - bajty.png', dpi=300)
# Wyświetl wykres
plt.show()

# %%
x1_1 = df_temp['Ilość bajtów']
y1_1 = df_temp['Przepustowość łącza - Blokujące']/(1024*1024)
x2_1 = df_temp['Ilość bajtów']
y2_1 = df_temp['Przepustowość łącza - Nieblokujące']/(1024*1024)

###############################################################

plt.plot(x1_1, y1_1, linestyle='solid', color='g', label='Blokujące')
plt.plot(x2_1, y2_1, linestyle='dotted', color='g', label='Nieblokujące')

# Dodaj etykiety osi
plt.xlabel('Ilość bajtów w wiadomości')
plt.ylabel('Przepustowość łącza [MB/s]')

# Dodaj tytuł wykresu
plt.title('Przepustowość łącza')
plt.legend()
plt.savefig('Przepustowość łącza - bajty.png', dpi=300)
# Wyświetl wykres
plt.show()

# %%
x1_1 = df_temp['Ilość bajtów']
y1_1 = df_temp['Czas wykonania pojedynczej operacji - Blokujące']
x2_1 = df_temp['Ilość bajtów']
y2_1 = df_temp['Czas wykonania pojedynczej operacji - Nieblokujące']

###############################################################

plt.plot(x1_1, y1_1, linestyle='solid', color='b', label='Blokujące')
plt.plot(x2_1, y2_1, linestyle='dotted', color='b', label='Nieblokujące')

# Dodaj etykiety osi
plt.xlabel('Ilość bajtów w wiadomości')
plt.ylabel('Czas wykonania pojedynczej operacji (µs)')

# Dodaj tytuł wykresu
plt.title('Czas wykonania pojedynczej operacji')
plt.legend()
plt.savefig('Czas wykonania pojedynczej operacji - bajty.png', dpi=300)
# Wyświetl wykres
plt.show()

# %%
y1_1 = df_temp['Przepustowość łącza - Blokujące']/(1024*1024)
x1_1 = df_temp['Czas wykonania pojedynczej operacji - Blokujące']
y2_1 = df_temp['Przepustowość łącza - Nieblokujące']/(1024*1024)
x2_1 = df_temp['Czas wykonania pojedynczej operacji - Nieblokujące']

###############################################################

plt.plot(x1_1, y1_1, linestyle='solid', color='b', label='Blokujące')
plt.plot(x2_1, y2_1, linestyle='dotted', color='b', label='Nieblokujące')

# Dodaj etykiety osi
plt.xlabel('Czas wykonania pojedynczej operacji [µs]')
plt.ylabel('Przepustowość łącza [MB/s]')

plt.gca().xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))

# Dodaj tytuł wykresu
plt.title('Czas wykonania pojedynczej operacji')
plt.legend()
plt.savefig('aa.png', dpi=300)
# Wyświetl wykres
plt.show()

# %%
y1_1 = df_temp['Przepustowość łącza - Blokujące']/(1024*1024)
x1_1 = df_temp['Czas trwania wszystkich operacji - Blokujące']
y2_1 = df_temp['Przepustowość łącza - Nieblokujące']/(1024*1024)
x2_1 = df_temp['Czas trwania wszystkich operacji - Nieblokujące']

###############################################################

plt.plot(x1_1, y1_1, linestyle='solid', color='b', label='Blokujące')
plt.plot(x2_1, y2_1, linestyle='dotted', color='b', label='Nieblokujące')

# Dodaj etykiety osi
plt.xlabel('Czas trwania wszystkich operacji [s]')
plt.ylabel('Przepustowość łącza [MB/s]')

plt.gca().xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))

# Dodaj tytuł wykresu
plt.title('Czas wykonania pojedynczej operacji')
plt.legend()
plt.savefig('aa.png', dpi=300)
# Wyświetl wykres
plt.show()
